# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Primero, una "serie"
s=pd.Series([61,81,81,11.0, np.nan, 0.71]) # el argumento es un array de numpy
s
# Out:
# 0    61.00
# 1    81.00
# 2    81.00
# 3    11.00
# 4      NaN
# 5     0.71
# dtype: float64

# %%
fechas=pd.date_range('20170901',periods=30)

# %%
df=pd.DataFrame(np.random.randn(30,4), index=fechas, columns=list('ABCD')) 
#un data frame de una matriz y un indice de renglones y uno de columnas.

# %%
list('tuabuela')
# Out:
# ['t', 'u', 'a', 'b', 'u', 'e', 'l', 'a']

# %%
list(range(2,5))
# Out:
# [2, 3, 4]

# %%
df2=pd.DataFrame({'A': 1.0,
     'B':pd.Timestamp('20170401'),
    'C': pd.Series(1.0, index=list(range(4)), dtype='float64'),
     'D':np.array([3]*4,dtype='int32'),
     'E': pd.Categorical(['coche', 'vocho','coche','vocho']),
     'F': 'foobar'})
#un data frame de un diccionario de cosas que parecen series

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float64
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.tail(2)
# Out:
#                    A         B         C         D
# 2017-09-29 -0.315396  1.239465  0.687471 -0.366857
# 2017-09-30  0.277615  0.239026 -0.886053  1.023916

# %%
df.index
# Out:
# DatetimeIndex(['2017-09-01', '2017-09-02', '2017-09-03', '2017-09-04',
#                '2017-09-05', '2017-09-06', '2017-09-07', '2017-09-08',
#                '2017-09-09', '2017-09-10', '2017-09-11', '2017-09-12',
#                '2017-09-13', '2017-09-14', '2017-09-15', '2017-09-16',
#                '2017-09-17', '2017-09-18', '2017-09-19', '2017-09-20',
#                '2017-09-21', '2017-09-22', '2017-09-23', '2017-09-24',
#                '2017-09-25', '2017-09-26', '2017-09-27', '2017-09-28',
#                '2017-09-29', '2017-09-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
# ?df.describe()

# %%
df.sort_values(by='A')
# Out:
#                    A         B         C         D
# 2017-09-25 -1.730513  0.977572  1.919968 -0.016728
# 2017-09-19 -1.643307  1.378635 -0.753756  0.002902
# 2017-09-21 -1.477026  1.287190 -1.756385  1.467204
# 2017-09-13 -1.064817 -2.540371 -2.827416 -0.671159
# 2017-09-14 -1.057347  0.597143  0.482439 -2.436903
# 2017-09-22 -0.827617  0.287472  0.662871  0.197967
# 2017-09-12 -0.477831  0.913096  0.798273 -0.141471
# 2017-09-29 -0.315396  1.239465  0.687471 -0.366857
# 2017-09-23 -0.255118 -0.220621  0.041422 -0.471563
# 2017-09-26  0.066394  0.514936  0.874882  1.500753
# 2017-09-09  0.077166  0.623903  1.189766  1.521585
# 2017-09-02  0.257165 -1.566067  0.903160 -0.115707
# 2017-09-30  0.277615  0.239026 -0.886053  1.023916
# 2017-09-20  0.307183 -0.136864  0.558090  0.235040
# 2017-09-01  0.326629 -0.383042 -0.167567 -0.628632
# 2017-09-17  0.473481 -0.488662 -1.786425 -0.309776
# 2017-09-06  0.628813 -0.348654 -1.226361 -0.550353
# 2017-09-08  0.648860 -0.160206 -0.611942  0.849329
# 2017-09-05  0.670036 -2.402952  1.152809  1.013061
# 2017-09-11  0.728208  0.381941 -0.415060  1.558651
# 2017-09-07  0.908267 -0.057876 -1.673259  1.166140
# 2017-09-28  0.996921  0.783261  2.113421  1.090247
# 2017-09-15  0.998224 -0.572435  1.484165  1.508471
# 2017-09-03  1.210751 -0.749706  1.498882 -0.845130
# 2017-09-27  1.367348 -1.441670 -0.911920  0.628771
# 2017-09-10  1.447265 -0.724669  0.440511 -0.218194
# 2017-09-24  1.624562  0.767268  0.225148  0.132675
# 2017-09-16  1.654972  0.661847 -1.875958 -0.209289
# 2017-09-04  1.798815  1.875299 -0.925746 -0.098970
# 2017-09-18  2.148219 -0.308368  0.185405 -1.906992

# %%
df['A'].dtype
# Out:
# dtype('float64')

# %%
df[6:20]==df['20170907':'20170920']
# Out:
#                A     B     C     D
# 2017-09-07  True  True  True  True
# 2017-09-08  True  True  True  True
# 2017-09-09  True  True  True  True
# 2017-09-10  True  True  True  True
# 2017-09-11  True  True  True  True
# 2017-09-12  True  True  True  True
# 2017-09-13  True  True  True  True
# 2017-09-14  True  True  True  True
# 2017-09-15  True  True  True  True
# 2017-09-16  True  True  True  True
# 2017-09-17  True  True  True  True
# 2017-09-18  True  True  True  True
# 2017-09-19  True  True  True  True
# 2017-09-20  True  True  True  True

# %%
a=df.loc[fechas[6]]

# %%
a.dtype
# Out:
# dtype('float64')

# %%
df.loc[:,['B','D']]
# Out:
#                    B         D
# 2017-09-01 -0.383042 -0.628632
# 2017-09-02 -1.566067 -0.115707
# 2017-09-03 -0.749706 -0.845130
# 2017-09-04  1.875299 -0.098970
# 2017-09-05 -2.402952  1.013061
# 2017-09-06 -0.348654 -0.550353
# 2017-09-07 -0.057876  1.166140
# 2017-09-08 -0.160206  0.849329
# 2017-09-09  0.623903  1.521585
# 2017-09-10 -0.724669 -0.218194
# 2017-09-11  0.381941  1.558651
# 2017-09-12  0.913096 -0.141471
# 2017-09-13 -2.540371 -0.671159
# 2017-09-14  0.597143 -2.436903
# 2017-09-15 -0.572435  1.508471
# 2017-09-16  0.661847 -0.209289
# 2017-09-17 -0.488662 -0.309776
# 2017-09-18 -0.308368 -1.906992
# 2017-09-19  1.378635  0.002902
# 2017-09-20 -0.136864  0.235040
# 2017-09-21  1.287190  1.467204
# 2017-09-22  0.287472  0.197967
# 2017-09-23 -0.220621 -0.471563
# 2017-09-24  0.767268  0.132675
# 2017-09-25  0.977572 -0.016728
# 2017-09-26  0.514936  1.500753
# 2017-09-27 -1.441670  0.628771
# 2017-09-28  0.783261  1.090247
# 2017-09-29  1.239465 -0.366857
# 2017-09-30  0.239026  1.023916

# %%
df.loc['20170907':'20170920',['B','D']] #aqui, con .loc NO puedes ponerlo con indices enteros
# Out:
#                    B         D
# 2017-09-07 -0.057876  1.166140
# 2017-09-08 -0.160206  0.849329
# 2017-09-09  0.623903  1.521585
# 2017-09-10 -0.724669 -0.218194
# 2017-09-11  0.381941  1.558651
# 2017-09-12  0.913096 -0.141471
# 2017-09-13 -2.540371 -0.671159
# 2017-09-14  0.597143 -2.436903
# 2017-09-15 -0.572435  1.508471
# 2017-09-16  0.661847 -0.209289
# 2017-09-17 -0.488662 -0.309776
# 2017-09-18 -0.308368 -1.906992
# 2017-09-19  1.378635  0.002902
# 2017-09-20 -0.136864  0.235040

# %%
type(df.loc['20170920',['B','D']]) # si reducimos mucho la dimension se convierte en otro objeto
# Out:
# pandas.core.series.Series

# %%
type(df.loc[fechas[6],'A'])
# Out:
# numpy.float64

# %%
df.iloc[1]  # con indices a la python recuerda. 0 es el 1!....
# Out:
# A    0.257165
# B   -1.566067
# C    0.903160
# D   -0.115707
# Name: 2017-09-02 00:00:00, dtype: float64

# %%
df.iloc[3:5,2:4] #again, python style, el endpoint NO esta incluido
# Out:
#                    C         D
# 2017-09-04 -0.925746 -0.098970
# 2017-09-05  1.152809  1.013061

# %%
df.iloc[[2,7,9],[0,2]]
# Out:
#                    A         C
# 2017-09-03  1.210751  1.498882
# 2017-09-08  0.648860 -0.611942
# 2017-09-10  1.447265  0.440511

# %%
df.iloc[24,2]
# Out:
# 1.9199682073088749

# %%
df.iat[24,2] # este es un metodo rapido para localizar un valor
# Out:
# 1.9199682073088749

# %%
df[df.A>0] #condiciones booleanas
# Out:
#                    A         B         C         D
# 2017-09-01  0.326629 -0.383042 -0.167567 -0.628632
# 2017-09-02  0.257165 -1.566067  0.903160 -0.115707
# 2017-09-03  1.210751 -0.749706  1.498882 -0.845130
# 2017-09-04  1.798815  1.875299 -0.925746 -0.098970
# 2017-09-05  0.670036 -2.402952  1.152809  1.013061
# 2017-09-06  0.628813 -0.348654 -1.226361 -0.550353
# 2017-09-07  0.908267 -0.057876 -1.673259  1.166140
# 2017-09-08  0.648860 -0.160206 -0.611942  0.849329
# 2017-09-09  0.077166  0.623903  1.189766  1.521585
# 2017-09-10  1.447265 -0.724669  0.440511 -0.218194
# 2017-09-11  0.728208  0.381941 -0.415060  1.558651
# 2017-09-15  0.998224 -0.572435  1.484165  1.508471
# 2017-09-16  1.654972  0.661847 -1.875958 -0.209289
# 2017-09-17  0.473481 -0.488662 -1.786425 -0.309776
# 2017-09-18  2.148219 -0.308368  0.185405 -1.906992
# 2017-09-20  0.307183 -0.136864  0.558090  0.235040
# 2017-09-24  1.624562  0.767268  0.225148  0.132675
# 2017-09-26  0.066394  0.514936  0.874882  1.500753
# 2017-09-27  1.367348 -1.441670 -0.911920  0.628771
# 2017-09-28  0.996921  0.783261  2.113421  1.090247
# 2017-09-30  0.277615  0.239026 -0.886053  1.023916

# %%
df[df>0] # "purga" booleanamnte el df.
# Out:
#                    A         B         C         D
# 2017-09-01  0.326629       NaN       NaN       NaN
# 2017-09-02  0.257165       NaN  0.903160       NaN
# 2017-09-03  1.210751       NaN  1.498882       NaN
# 2017-09-04  1.798815  1.875299       NaN       NaN
# 2017-09-05  0.670036       NaN  1.152809  1.013061
# 2017-09-06  0.628813       NaN       NaN       NaN
# 2017-09-07  0.908267       NaN       NaN  1.166140
# 2017-09-08  0.648860       NaN       NaN  0.849329
# 2017-09-09  0.077166  0.623903  1.189766  1.521585
# 2017-09-10  1.447265       NaN  0.440511       NaN
# 2017-09-11  0.728208  0.381941       NaN  1.558651
# 2017-09-12       NaN  0.913096  0.798273       NaN
# 2017-09-13       NaN       NaN       NaN       NaN
# 2017-09-14       NaN  0.597143  0.482439       NaN
# 2017-09-15  0.998224       NaN  1.484165  1.508471
# 2017-09-16  1.654972  0.661847       NaN       NaN
# 2017-09-17  0.473481       NaN       NaN       NaN
# 2017-09-18  2.148219       NaN  0.185405       NaN
# 2017-09-19       NaN  1.378635       NaN  0.002902
# 2017-09-20  0.307183       NaN  0.558090  0.235040
# 2017-09-21       NaN  1.287190       NaN  1.467204
# 2017-09-22       NaN  0.287472  0.662871  0.197967
# 2017-09-23       NaN       NaN  0.041422       NaN
# 2017-09-24  1.624562  0.767268  0.225148  0.132675
# 2017-09-25       NaN  0.977572  1.919968       NaN
# 2017-09-26  0.066394  0.514936  0.874882  1.500753
# 2017-09-27  1.367348       NaN       NaN  0.628771
# 2017-09-28  0.996921  0.783261  2.113421  1.090247
# 2017-09-29       NaN  1.239465  0.687471       NaN
# 2017-09-30  0.277615  0.239026       NaN  1.023916

# %%
df3=df2.copy()

# %%
df3['G']=['one', 'one','two','three']
df3
# Out:
#      A          B    C  D      E       F      G
# 0  1.0 2017-04-01  1.0  3  coche  foobar    one
# 1  1.0 2017-04-01  1.0  3  vocho  foobar    one
# 2  1.0 2017-04-01  1.0  3  coche  foobar    two
# 3  1.0 2017-04-01  1.0  3  vocho  foobar  three

# %%
df3[df3['G'].isin(['two','three'])]
# Out:
#      A          B    C  D      E       F      G
# 2  1.0 2017-04-01  1.0  3  coche  foobar    two
# 3  1.0 2017-04-01  1.0  3  vocho  foobar  three

# %%
s1=pd.Series(range(30),index=pd.date_range('20170901',periods=30))

# %%
df['F']=s1

# %%
df.at[fechas[17], 'B']=0

# %%
df.iat[7,3]=0

# %%
df.loc[:,'D']=np.array([5]*len(df))

# %%
len(df)
# Out:
# 30

# %%
df1=df.reindex(index=fechas[6:21],columns=list(df.columns)+['H'])
df1.loc[fechas[6]:fechas[11],'H'] = 1

# %%
df1.dropna(how='any')
# Out:
#                    A         B         C  D   F    H
# 2017-09-07  0.908267 -0.057876 -1.673259  5   6  1.0
# 2017-09-08  0.648860 -0.160206 -0.611942  5   7  1.0
# 2017-09-09  0.077166  0.623903  1.189766  5   8  1.0
# 2017-09-10  1.447265 -0.724669  0.440511  5   9  1.0
# 2017-09-11  0.728208  0.381941 -0.415060  5  10  1.0
# 2017-09-12 -0.477831  0.913096  0.798273  5  11  1.0

# %%
df1.fillna(value=0.0)
# Out:
#                    A         B         C  D   F    H
# 2017-09-07  0.908267 -0.057876 -1.673259  5   6  1.0
# 2017-09-08  0.648860 -0.160206 -0.611942  5   7  1.0
# 2017-09-09  0.077166  0.623903  1.189766  5   8  1.0
# 2017-09-10  1.447265 -0.724669  0.440511  5   9  1.0
# 2017-09-11  0.728208  0.381941 -0.415060  5  10  1.0
# 2017-09-12 -0.477831  0.913096  0.798273  5  11  1.0
# 2017-09-13 -1.064817 -2.540371 -2.827416  5  12  0.0
# 2017-09-14 -1.057347  0.597143  0.482439  5  13  0.0
# 2017-09-15  0.998224 -0.572435  1.484165  5  14  0.0
# 2017-09-16  1.654972  0.661847 -1.875958  5  15  0.0
# 2017-09-17  0.473481 -0.488662 -1.786425  5  16  0.0
# 2017-09-18  2.148219  0.000000  0.185405  5  17  0.0
# 2017-09-19 -1.643307  1.378635 -0.753756  5  18  0.0
# 2017-09-20  0.307183 -0.136864  0.558090  5  19  0.0
# 2017-09-21 -1.477026  1.287190 -1.756385  5  20  0.0

# %%
pd.isnull(df1)
# Out:
#                 A      B      C      D      F      H
# 2017-09-07  False  False  False  False  False  False
# 2017-09-08  False  False  False  False  False  False
# 2017-09-09  False  False  False  False  False  False
# 2017-09-10  False  False  False  False  False  False
# 2017-09-11  False  False  False  False  False  False
# 2017-09-12  False  False  False  False  False  False
# 2017-09-13  False  False  False  False  False   True
# 2017-09-14  False  False  False  False  False   True
# 2017-09-15  False  False  False  False  False   True
# 2017-09-16  False  False  False  False  False   True
# 2017-09-17  False  False  False  False  False   True
# 2017-09-18  False  False  False  False  False   True
# 2017-09-19  False  False  False  False  False   True
# 2017-09-20  False  False  False  False  False   True
# 2017-09-21  False  False  False  False  False   True

# %%
tub=df.mean(1)

# %%
type(tub)
# Out:
# pandas.core.series.Series

# %%
# ?pd.Series.shift

# %%
df1.apply(np.cumsum)
# Out:
#                    A         B         C   D    F    H
# 2017-09-07  0.908267 -0.057876 -1.673259   5    6  1.0
# 2017-09-08  1.557127 -0.218083 -2.285201  10   13  2.0
# 2017-09-09  1.634294  0.405820 -1.095435  15   21  3.0
# 2017-09-10  3.081559 -0.318849 -0.654924  20   30  4.0
# 2017-09-11  3.809766  0.063092 -1.069984  25   40  5.0
# 2017-09-12  3.331935  0.976187 -0.271710  30   51  6.0
# 2017-09-13  2.267118 -1.564184 -3.099126  35   63  NaN
# 2017-09-14  1.209771 -0.967040 -2.616687  40   76  NaN
# 2017-09-15  2.207995 -1.539475 -1.132522  45   90  NaN
# 2017-09-16  3.862967 -0.877628 -3.008480  50  105  NaN
# 2017-09-17  4.336448 -1.366290 -4.794906  55  121  NaN
# 2017-09-18  6.484667 -1.366290 -4.609500  60  138  NaN
# 2017-09-19  4.841360  0.012345 -5.363257  65  156  NaN
# 2017-09-20  5.148543 -0.124519 -4.805167  70  175  NaN
# 2017-09-21  3.671517  1.162671 -6.561552  75  195  NaN

# %%
df1.apply(lambda x : x.max()-x.min())
# Out:
# A     3.791525
# B     3.919006
# C     4.311580
# D     0.000000
# F    14.000000
# H     0.000000
# dtype: float64

# %%
len(df1)
# Out:
# 15

# %%
s=pd.Series(np.random.randn(15),index=fechas[1:16]).shift(3)
s
# Out:
# 2017-09-02         NaN
# 2017-09-03         NaN
# 2017-09-04         NaN
# 2017-09-05   -0.543488
# 2017-09-06    1.681717
# 2017-09-07    0.605842
# 2017-09-08   -0.097190
# 2017-09-09   -1.561260
# 2017-09-10    0.325516
# 2017-09-11    0.217123
# 2017-09-12   -0.143258
# 2017-09-13   -0.597866
# 2017-09-14   -0.846981
# 2017-09-15   -1.009470
# 2017-09-16    0.702348
# Freq: D, dtype: float64

# %%
df.sub(s,axis=0) #jaja el indice del objeto tiene que coincider, el resto da NaN.
# Out:
#                    A         B         C         D          F
# 2017-09-01       NaN       NaN       NaN       NaN        NaN
# 2017-09-02       NaN       NaN       NaN       NaN        NaN
# 2017-09-03       NaN       NaN       NaN       NaN        NaN
# 2017-09-04       NaN       NaN       NaN       NaN        NaN
# 2017-09-05  1.213525 -1.859464  1.696297  5.543488   4.543488
# 2017-09-06 -1.052904 -2.030371 -2.908077  3.318283   3.318283
# 2017-09-07  0.302426 -0.663718 -2.279100  4.394158   5.394158
# 2017-09-08  0.746050 -0.063016 -0.514752  5.097190   7.097190
# 2017-09-09  1.638426  2.185163  2.751026  6.561260   9.561260
# 2017-09-10  1.121749 -1.050185  0.114994  4.674484   8.674484
# 2017-09-11  0.511085  0.164818 -0.632182  4.782877   9.782877
# 2017-09-12 -0.334573  1.056353  0.941531  5.143258  11.143258
# 2017-09-13 -0.466951 -1.942505 -2.229550  5.597866  12.597866
# 2017-09-14 -0.210366  1.444124  1.329420  5.846981  13.846981
# 2017-09-15  2.007694  0.437035  2.493635  6.009470  15.009470
# 2017-09-16  0.952624 -0.040501 -2.578306  4.297652  14.297652
# 2017-09-17       NaN       NaN       NaN       NaN        NaN
# 2017-09-18       NaN       NaN       NaN       NaN        NaN
# 2017-09-19       NaN       NaN       NaN       NaN        NaN
# 2017-09-20       NaN       NaN       NaN       NaN        NaN
# 2017-09-21       NaN       NaN       NaN       NaN        NaN
# 2017-09-22       NaN       NaN       NaN       NaN        NaN
# 2017-09-23       NaN       NaN       NaN       NaN        NaN
# 2017-09-24       NaN       NaN       NaN       NaN        NaN
# 2017-09-25       NaN       NaN       NaN       NaN        NaN
# 2017-09-26       NaN       NaN       NaN       NaN        NaN
# 2017-09-27       NaN       NaN       NaN       NaN        NaN
# 2017-09-28       NaN       NaN       NaN       NaN        NaN
# 2017-09-29       NaN       NaN       NaN       NaN        NaN
# 2017-09-30       NaN       NaN       NaN       NaN        NaN

# %%
s = pd.Series(np.random.randint(0, 7, size=1000000))
s.value_counts()
# Out:
# 4    143247
# 5    143119
# 0    142931
# 3    142923
# 2    142680
# 6    142586
# 1    142514
# dtype: int64

# %%
df=pd.DataFrame(np.random.randn(10,4))
df
# Out:
#           0         1         2         3
# 0  0.137285  0.297154  0.171548 -0.128645
# 1 -0.108016 -0.475877  1.201848 -1.217694
# 2 -0.422768  0.500333 -2.040482 -1.665670
# 3 -0.095639 -0.692299 -2.465505 -0.268923
# 4 -3.833482  1.691953 -0.899187  0.343215
# 5  0.487191 -1.358217 -0.086605  1.189495
# 6 -0.977390 -0.038252  1.405167 -0.941978
# 7  1.180331 -1.654135  0.346042  0.240952
# 8  0.969509  0.138953  0.222236 -0.663623
# 9 -1.761499 -0.571067 -0.250187  0.264539

# %%
piezas=[df[:3],df[3:7], df[7:10]]

# %%
hola=pd.concat(piezas)

# %%
l=pd.DataFrame({'key': ['f','f'], 'lval': [1,2]})
r=pd.DataFrame({'key': ['f','f'], 'rval': [3,4]})

# %%
pd.merge(l,r, on='key') #fijate que es como un producto exterior, no una concatenación
# Out:
#   key  lval  rval
# 0   f     1     3
# 1   f     1     4
# 2   f     2     3
# 3   f     2     4

# %%
#checa la diferencia si la llave varia
l=pd.DataFrame({'key': ['f','b'], 'lval': [1,2]})
r=pd.DataFrame({'key': ['f','b'], 'rval': [3,4]})
pd.merge(l,r, on='key')
#ahora si concaetena
# Out:
#   key  lval  rval
# 0   f     1     3
# 1   b     2     4

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])

# %%
z=df.iloc[3]

# %%
df.append(z,ignore_index=True)
# Out:
#           A         B         C         D
# 0 -0.767788 -0.136818  1.440810 -0.605793
# 1 -1.705316 -0.155686  0.599728 -0.516589
# 2  0.741321 -0.280903 -0.033142 -0.727904
# 3  0.292913 -0.347763  0.491506 -0.026686
# 4 -0.066233  0.500802  0.679590  0.224047
# 5 -1.246492 -2.079915  0.706319  0.164896
# 6  1.019399 -1.678809 -0.379143  0.700698
# 7 -1.008037 -0.804170 -0.722020 -1.364594
# 8  0.292913 -0.347763  0.491506 -0.026686

# %% [markdown]
# # Agrupar:
# Dividir la categoria en grupos, aplicarles funciones por grupos y montar una estructura con los resultados.

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
   ....:                           'foo', 'bar', 'foo', 'foo'],
   ....:                    'B' : ['one', 'one', 'two', 'three',
   ....:                           'two', 'two', 'one', 'three'],
   ....:                    'C' : np.random.randn(8),
   ....:                    'D' : np.random.rand(8)})
   ....:

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -0.131467  0.160654
# 1  bar    one  0.858892  0.496569
# 2  foo    two -0.977784  0.322308
# 3  bar  three -0.617047  0.415203
# 4  foo    two  2.091679  0.619698
# 5  bar    two -0.592696  0.854866
# 6  foo    one  1.554374  0.176691
# 7  foo  three  0.541929  0.643526

# %%
# ?np.random.rand

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -0.350851  1.766638
# foo  3.078731  1.922877

# %%
zaca=df.groupby(['A','B']).sum()

# %%
zaca
# Out:
#                   C         D
# A   B
# bar one    0.858892  0.496569
#     three -0.617047  0.415203
#     two   -0.592696  0.854866
# foo one    1.422907  0.337345
#     three  0.541929  0.643526
#     two    1.113895  0.942006

# %%
type(zaca)
# Out:
# pandas.core.frame.DataFrame

# %%
# cuando tienes df mas complejas, no puedes hacer esto: zaca[1]
zaca.iloc[1]
# Out:
# C   -0.617047
# D    0.415203
# Name: (bar, three), dtype: float64

# %%
type(zaca.iloc[1])
# Out:
# pandas.core.series.Series

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
   ....:                      'foo', 'foo', 'qux', 'qux'],
   ....:                     ['one', 'two', 'one', 'two',
   ....:                      'one', 'two', 'one', 'two']])) 
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second']) #esto produe un multiindice complejo bien aca.

# %%
index
# Out:
# MultiIndex(levels=[['bar', 'baz', 'foo', 'qux'], ['one', 'two']],
#            labels=[[0, 0, 1, 1, 2, 2, 3, 3], [0, 1, 0, 1, 0, 1, 0, 1]],
#            names=['first', 'second'])

# %%
 df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])

# %%
df
# Out:
#                      A         B
# first second
# bar   one    -2.234958 -1.293329
#       two     0.560112  0.736848
# baz   one    -0.692440 -1.081915
#       two    -0.144566 -0.708938
# foo   one    -0.065578  0.359378
#       two     1.079613  0.137023
# qux   one     1.312041 -0.810467
#       two     0.704661 -1.059974

# %%
df2=df.stack()
df2 #¿que diablos paso: pasaste A y B com nuevas categorias. ... y se volvio una Serie!!!
# Out:
# first  second
# bar    one     A   -2.234958
#                B   -1.293329
#        two     A    0.560112
#                B    0.736848
# baz    one     A   -0.692440
#                B   -1.081915
#        two     A   -0.144566
#                B   -0.708938
# foo    one     A   -0.065578
#                B    0.359378
#        two     A    1.079613
#                B    0.137023
# qux    one     A    1.312041
#                B   -0.810467
#        two     A    0.704661
#                B   -1.059974
# dtype: float64

# %%
type(df2)
# Out:
# pandas.core.series.Series

# %%
df3=df2.unstack(1) # por omisión, unstack usa la ultima (mas derecha) categoría.

# %%
df3
# Out:
# second        one       two
# first
# bar   A -2.234958  0.560112
#       B -1.293329  0.736848
# baz   A -0.692440 -0.144566
#       B -1.081915 -0.708938
# foo   A -0.065578  1.079613
#       B  0.359378  0.137023
# qux   A  1.312041  0.704661
#       B -0.810467 -1.059974

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
   .....:                    'B' : ['A', 'B', 'C'] * 4,
   .....:                    'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
   .....:                    'D' : np.random.randn(12),
   .....:                    'E' : np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.193139 -0.418099
# 1     one  B  foo  1.079374  0.049005
# 2     two  C  foo  1.225275  0.075197
# 3   three  A  bar -2.050931 -0.367235
# 4     one  B  bar -0.109777 -1.624104
# 5     one  C  bar -2.280781 -0.183069
# 6     two  A  foo -0.395984 -0.875637
# 7   three  B  foo -0.898482  0.442921
# 8     one  C  foo -0.226354  0.442807
# 9     one  A  bar  2.775438  0.669008
# 10    two  B  bar  0.941288 -0.844898
# 11  three  C  bar  0.333138 -1.565617

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
   .....:                    'B' : ['A', 'B', 'C'] * 4,
   .....:                    'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
   .....:                    'D' : np.random.randn(12),
   .....:                    'E' : np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.157919 -0.593545
# 1     one  B  foo  0.494635 -0.347761
# 2     two  C  foo -0.959851  1.788112
# 3   three  A  bar  1.541009  0.442005
# 4     one  B  bar  1.489320  2.302111
# 5     one  C  bar -0.089991 -1.467944
# 6     two  A  foo -1.490669 -0.665215
# 7   three  B  foo  0.979848  0.123439
# 8     one  C  foo -1.686820  0.218859
# 9     one  A  bar  0.365699 -0.846794
# 10    two  B  bar -0.662386 -0.286645
# 11  three  C  bar -0.278540  0.599606

# %% [markdown]
# # Tablas de pivote ...
# es decir, tablas que son resumen de otras tablas usando alguna categoria como pivote...

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -0.474914  0.378476
#       B -1.381951  0.981261
#       C  0.387849 -1.001726
# three A  0.109716       NaN
#       B       NaN  1.069759
#       C -1.354667       NaN
# two   A       NaN  0.514819
#       B -0.692060       NaN
#       C       NaN -0.530788

# %% [markdown]
# # Fechas

# %%
rng=pd.date_range("23/9/2015",periods=1000, freq='S') # S es segundos!
ts=pd.Series(np.random.randint(0,500,len(rng)), index=rng)
ts.resample('4Min').sum() #super, funciona 5Min, 1Min ... ¿que mas? 10S...
# woooow
# Out:
# 2015-09-23 00:00:00    56938
# 2015-09-23 00:04:00    65262
# 2015-09-23 00:08:00    59079
# 2015-09-23 00:12:00    61924
# 2015-09-23 00:16:00    10021
# Freq: 4T, dtype: int64

# %%
rng = pd.date_range('3/6/2012 02:00', periods=5, freq='D') # D es un dia 
ts = pd.Series(np.random.randn(len(rng)), rng)
ts_utc = ts.tz_localize('UTC')

# %%
ts_utc.tz_convert('America/Mexico_City') # SUuper
# Out:
# 2012-03-05 20:00:00-06:00    0.786341
# 2012-03-06 20:00:00-06:00   -1.600112
# 2012-03-07 20:00:00-06:00   -0.634987
# 2012-03-08 20:00:00-06:00   -1.395588
# 2012-03-09 20:00:00-06:00   -1.588210
# Freq: D, dtype: float64

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ps=ts.to_period()

# %%
ps
# Out:
# 2012-01   -0.154534
# 2012-02   -0.796161
# 2012-03   -0.526633
# 2012-04    0.835678
# 2012-05    1.503910
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01   -0.154534
# 2012-02-01   -0.796161
# 2012-03-01   -0.526633
# 2012-04-01    0.835678
# 2012-05-01    1.503910
# Freq: MS, dtype: float64

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')
ts = pd.Series(np.random.randn(len(prng)), prng)
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9
ts.head()
# Out:
# 1990-03-01 09:00   -0.663228
# 1990-06-01 09:00   -0.617907
# 1990-09-01 09:00   -1.637802
# 1990-12-01 09:00    0.690745
# 1991-03-01 09:00    0.198480
# Freq: H, dtype: float64

# %%
prng.asfreq('D','e')
# Out:
# PeriodIndex(['1990-02-28', '1990-05-31', '1990-08-31', '1990-11-30',
#              '1991-02-28', '1991-05-31', '1991-08-31', '1991-11-30',
#              '1992-02-29', '1992-05-31', '1992-08-31', '1992-11-30',
#              '1993-02-28', '1993-05-31', '1993-08-31', '1993-11-30',
#              '1994-02-28', '1994-05-31', '1994-08-31', '1994-11-30',
#              '1995-02-28', '1995-05-31', '1995-08-31', '1995-11-30',
#              '1996-02-29', '1996-05-31', '1996-08-31', '1996-11-30',
#              '1997-02-28', '1997-05-31', '1997-08-31', '1997-11-30',
#              '1998-02-28', '1998-05-31', '1998-08-31', '1998-11-30',
#              '1999-02-28', '1999-05-31', '1999-08-31', '1999-11-30',
#              '2000-02-29', '2000-05-31', '2000-08-31', '2000-11-30'],
#             dtype='period[D]', freq='D')

# %%
# ?prng.asfreq

# %% [markdown]
# # Categorias

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})

# %%
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df["grade"] = df["raw_grade"].astype("category")
df["grade"].cat.categories
# Out:
# Index(['a', 'b', 'e'], dtype='object')

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium", "good", "very good"])
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# # Plotting

# %%
ts2=ts.cumsum()

# %%
lala=ts2.plot()
plt.show()
